# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Scatter Plot:
#
# Use: To visualize the relationship between two numerical variables. It helps in identifying patterns, trends, or correlations.
#
# Bar Plot:
#
# Use: Useful for comparing categorical data. It can show the distribution of a single categorical variable or the relationship between two categorical variables.
#
# Box Plot (or Box-and-Whisker Plot):
#
# Use: Display the distribution of a dataset and identify potential outliers. It shows the median, quartiles, and possible outliers.
#
# Violin Plot:
#
# Use: Similar to a box plot but also includes a rotated kernel density plot on each side. Useful for visualizing the distribution of data across different categories.
#
# Violin Plot:
#
# Use: Similar to a box plot but also includes a rotated kernel density plot on each side. Useful for visualizing the distribution of data across different categories.

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %% [markdown]
# Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fmri = sns.load_dataset('fmri')

sns.lineplot(x='timepoint', y='signal', data=fmri)
plt.title('Line Plot for fmri Dataset')
plt.show()

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %% [markdown]
# Note: pclass, age, and fare are columns in the titanic dataset.

# %%
titanic = sns.load_dataset('titanic')

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x='pclass', y='age', data=titanic)
plt.title('Box Plot of Age by Pclass')

plt.subplot(1, 2, 2)
sns.boxplot(x='pclass', y='fare', data=titanic)
plt.title('Box Plot of Fare by Pclass')

plt.show()

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
diamonds = sns.load_dataset('diamonds')

sns.histplot(data=diamonds, x='price', hue='cut', multiple='stack', bins=30)
plt.title('Histogram of Price with Cut Variation')
plt.show()

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris = sns.load_dataset('iris')

# Pair plot with hue
sns.pairplot(data=iris, hue='species')
plt.title('Pair Plot of Iris Dataset with Species Hue')
plt.show()

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights')

flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')

sns.heatmap(flights_pivot, cmap='viridis', annot=True, fmt='d', linewidths=.5)
plt.title('Heatmap of Flights Dataset')
plt.show()
